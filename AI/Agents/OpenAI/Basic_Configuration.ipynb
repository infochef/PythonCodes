# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f'OpenAI API Key exists and begins {openai_api_key[:8]}')
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI
from IPython.display import Markdown, display

openai = OpenAI()
messages = [{"role": "user", "content": "Tell me a fun fact"}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# A fun fact: **Octopuses have three hearts**—two pump blood to the gills, and one pumps it to the rest of the body. Also, their blood is **blue** because it uses copper-based hemocyanin to carry oxygen.

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
display(Markdown(answer))
# Out:
# A sealed box contains 12 identical-looking coins: 11 are fair, and 1 is a fake coin that is either always heads or always tails, but you do not know which. You may choose any subset of coins and flip them all at once, as many times as you want, but after each flip the box is shaken so you cannot track individual coins—only the total number of heads showing among the 12 coins. What is the minimum number of flips required, in the worst case, to determine with certainty which coin is fake and whether it is always heads or always tails?
# **Minimum worst-case number of flips: 4**
#
# ### Why 4 is enough
# You can use the fact that the fake coin behaves differently from fair coins no matter what subset you flip:
#
# - If the fake coin is **always heads**, then flipping a subset containing it does **not** change its face.
# - If it is **always tails**, same idea.
# - Fair coins behave normally, so the **total number of heads** after each flip changes in a way that depends on whether the fake coin was included.
#
# By choosing subsets cleverly, you can encode each coin in a binary-search-style elimination process:
#
# 1. Flip half the coins.
# 2. Use the change in total heads to determine which half contains the fake, or whether the fake coin’s fixed face explains the result.
# 3. Repeat on the remaining half.
# 4. Continue until only one coin remains.
#
# Since there are 12 coins, distinguishing among 12 possible coins and 2 possible fake types requires at least
# \[
# \lceil \log_2(24) \rceil = 5
# \]
# possible states **if each flip only gave one bit** — but here a flip gives more structure because you observe the total heads count, not just a yes/no outcome. That extra information lets you do it in **4** flips.
#
# ---
#
# ### Why you cannot always do it in 3 flips
# In the worst case, 3 flips are not enough because the number of possible hidden situations is:
#
# - 12 choices for which coin is fake
# - 2 choices for whether it is always heads or always tails
#
# So there are **24 possibilities**.
# Three flips do not always provide enough distinguishable outcomes to guarantee identifying all 24 cases under this restricted observation model.
#
# ---
#
# ## Final answer
# \[
# \boxed{4}
# \]
#
# If you want, I can also give an explicit 4-flip strategy.
